# %%
# libraries

import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://cli.fusio.net/cli/climate_data/webdata/mly4935.csv', skiprows=19)
df.head()
# Out:
#    year  month  meant maxtp mintp  mnmax  mnmin   rain  gmin wdsp maxgt   sun
# 0  1996      8   13.4  20.4   7.3   16.6   10.3  109.4   5.3  8.3    34
# 1  1996     10    9.7               12.5    7.0
# 2  1996     11    5.0                7.6    2.5
# 3  1996     12    3.1  10.7  -4.0    5.2    1.1         -5.3  9.4    48
# 4  1997      1    3.4  10.7  -3.9    5.2    1.6   26.0  -5.2  8.0    40  42.1

# %%
corrtemp = df['month'].corr(df['meant'])
corrtemp
# Out:
# 0.26100201022623015

# %%
cleandf = df[['month','wdsp']]

# %%
cleandf['wdsp']=cleandf.loc[:,('wdsp')].replace(' ', np.nan)
cleandf.dropna(inplace=True)
cleandf['wdsp'] = cleandf['wdsp'].astype(float)
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_15936\4273236493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleandf['wdsp']=cleandf.loc[:,('wdsp')].replace(' ', np.nan)
# C:\Users\brian\AppData\Local\Temp\ipykernel_15936\4273236493.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleandf.dropna(inplace=True)
# C:\Users\brian\AppData\Local\Temp\ipykernel_15936\4273236493.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleandf['wdsp'] = cleandf['wdsp'].astype(float)

# %%
corrwind = cleandf['month'].corr(cleandf['wdsp'])
corrwind
# Out:
# -0.19999237419389979

# %%
sns.set_style('whitegrid')
sns.lmplot (x='month', y='wdsp', order=3, data=cleandf)
plt.show()
