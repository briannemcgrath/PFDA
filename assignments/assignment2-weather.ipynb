# %% [markdown]
# ## Week Two Assignment:
# Create a jupyter notebook that has a nice plot of the temperature over time.
#
# Author: Brianne McGrath

# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Loading the weatherreadings dataset
df = pd.read_csv('weatherreadings1.csv')

# %%
# Reviewing 'dryBulbTemperature_Celcius' data
temperature_data = df[['reportStartDateTime', 'dryBulbTemperature_Celsius']]
temperature_data.head()
# Out:
#          reportStartDateTime  dryBulbTemperature_Celsius
# 0  2024-10-02T16:15:00+00:00                   15.944444
# 1  2024-10-02T16:45:00+00:00                   15.777778
# 2  2024-10-02T17:00:00+00:00                   15.111111
# 3  2024-10-02T17:15:00+00:00                   14.277778
# 4  2024-10-02T17:30:00+00:00                   13.666667

# %%
#Checking date range
display(temperature_data)
# Out:
#           reportStartDateTime  dryBulbTemperature_Celsius
# 0   2024-10-02T16:15:00+00:00                   15.944444
# 1   2024-10-02T16:45:00+00:00                   15.777778
# 2   2024-10-02T17:00:00+00:00                   15.111111
# 3   2024-10-02T17:15:00+00:00                   14.277778
# 4   2024-10-02T17:30:00+00:00                   13.666667
# ..                        ...                         ...
# 84  2024-10-03T14:00:00+00:00                   14.611111
# 85  2024-10-03T14:15:00+00:00                   14.944444
# 86  2024-10-03T14:30:00+00:00                   14.944444
# 87  2024-10-03T14:45:00+00:00                   14.944444
# 88  2024-10-03T15:00:00+00:00                   14.722222
#
# [89 rows x 2 columns]

# %%
# Plotting the temperature over time
plt.figure(figsize=(14,8))
plt.plot(temperature_data['reportStartDateTime'], temperature_data['dryBulbTemperature_Celsius'], color='lightseagreen', marker='o', linestyle='-')
plt.title('Dry Bulb Temperature (Celcius) Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=7))  # Show every 7 days - this is incorrect, the range is only over 2 days. 15 minute intervals of time?
date_form = mdates.DateFormatter("%m-%d")  # Format dates as "MM-DD"
plt.gca().xaxis.set_major_formatter(date_form)
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## References:
#
# - https://www.statology.org/module-matplotlib-has-no-attribute-plot/ (Error message: AttributeError: module 'matplotlib' has no attribute 'figure')
# - https://www.earthdatascience.org/courses/use-data-open-source-python/use-time-series-data-in-python/date-time-types-in-pandas-python/customize-dates-matplotlib-plots-python/ (Reformatting Dates for Labelling)
